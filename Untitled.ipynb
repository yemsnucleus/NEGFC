# %%
import matplotlib.pyplot as plt
import tensorflow as tf

from src.preprocess import preprocess_folder
from src.format_data import create_dataset
from src.model import create_embedding_model
from src.losses import get_companion_std

from tensorflow.keras.optimizers import Adam
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "2"

# %load_ext autoreload
# %autoreload 2
# Out:
# 2023-06-05 16:20:02.909751: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-06-05 16:20:03.746644: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/home/users/cdonoso/miniconda3/envs/tf2/lib/:/home/users/cdonoso/miniconda3/envs/tf2/lib/python3.9/site-packages/nvidia/cudnn/lib
# 2023-06-05 16:20:03.746712: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/home/users/cdonoso/miniconda3/envs/tf2/lib/:/home/users/cdonoso/miniconda3/envs/tf2/lib/python3.9/site-packages/nvidia/cudnn/lib
# 2023-06-05 16:20:03.746717: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# /home/users/cdonoso/miniconda3/envs/tf2/lib/python3.9/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/home/users/cdonoso/miniconda3/envs/tf2/lib/python3.9/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/home/users/cdonoso/miniconda3/envs/tf2/lib/python3.9/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl6StatusC1EN10tensorflow5error4CodeESt17basic_string_viewIcSt11char_traitsIcEENS_18SourceLocationImplE']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# /home/users/cdonoso/miniconda3/envs/tf2/lib/python3.9/site-packages/tensorflow_io/python/ops/__init__.py:104: UserWarning: file system plugins are not loaded: unable to open file: libtensorflow_io.so, from paths: ['/home/users/cdonoso/miniconda3/envs/tf2/lib/python3.9/site-packages/tensorflow_io/python/ops/libtensorflow_io.so']
# caused by: ['/home/users/cdonoso/miniconda3/envs/tf2/lib/python3.9/site-packages/tensorflow_io/python/ops/libtensorflow_io.so: undefined symbol: _ZTVN3tsl13GcsFileSystemE']
#   warnings.warn(f"file system plugins are not loaded: {e}")
# /home/users/cdonoso/miniconda3/envs/tf2/lib/python3.9/site-packages/tensorflow_addons/utils/tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(

# %%
cube, psf, rot_angles, table = preprocess_folder(root='./data/fake', 
												 target_folder='./data/fake/preprocessed')

table = table[table['snr'] > 2]
dataset = create_dataset(cube, psf, rot_angles, table, window_size=15,
                         batch_size=2000, repeat=5)

model = create_embedding_model(window_size=20)

optimizer = Adam(1e-3)
model.compile(loss_fn=get_companion_std, optimizer=optimizer)

es = tf.keras.callbacks.EarlyStopping(
        monitor='loss',
        min_delta=1e-3,
        patience=20,
        mode='min',
        restore_best_weights=True,
        start_from_epoch=5
    )
# Out:
# [INFO] Restoring saved values

# %%
model.summary()
# Out:
# Model: "ConvNet"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  psf (InputLayer)               [(None, 20, 20, 1)]  0           []
#
#  psfCNN (PSFConvBlock)          (None, 288)          19104       ['psf[0][0]']
#
#  flux (InputLayer)              [(None,)]            0           []
#
#  fluxREG (FluxRegressor)        (None,)              19137       ['psfCNN[0][0]']
#
#  window (InputLayer)            [(None, 20, 20, 1)]  0           []
#
#  tf.__operators__.add_1 (TFOpLa  (None,)             0           ['flux[0][0]',
#  mbda)                                                            'fluxREG[0][0]']
#
#  cubeCNN (CubeConvBlock)        (None, 288)          19104       ['window[0][0]']
#
#  tf.compat.v1.shape_1 (TFOpLamb  (1,)                0           ['tf.__operators__.add_1[0][0]']
#  da)
#
#  dxdyREG (PositionRegressor)    ((None, 1),          19202       ['cubeCNN[0][0]']
#                                  (None, 1))
#
#  tf.__operators__.getitem_1 (Sl  ()                  0           ['tf.compat.v1.shape_1[0][0]']
#  icingOpLambda)
#
#  shift (TranslateCube)          (None, 20, 20)       0           ['psf[0][0]',
#                                                                   'dxdyREG[0][0]',
#                                                                   'dxdyREG[0][1]']
#
#  tf.reshape_1 (TFOpLambda)      (None, 1, 1)         0           ['tf.__operators__.add_1[0][0]',
#                                                                   'tf.__operators__.getitem_1[0][0
#                                                                  ]']
#
#  tf.math.multiply_1 (TFOpLambda  (None, 20, 20)      0           ['shift[0][0]',
#  )                                                                'tf.reshape_1[0][0]']
#
# ==================================================================================================
# Total params: 76,547
# Trainable params: 76,547
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# %%time
hist = model.fit(dataset, epochs=1000, callbacks=[es])
# Out:
# Epoch 1/1000
# 2023-06-05 16:20:35.172245: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 9.1.108, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-06-05 16:20:35.174210: W tensorflow/compiler/xla/stream_executor/gpu/redzone_allocator.cc:318] UNIMPLEMENTED: ptxas ptxas too old. Falling back to the driver to compile.
# Relying on driver to perform ptx compilation.
# Modify $PATH to customize ptxas location.
# This message will be only logged once.
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# <timed exec> in <module>
#
# ~/miniconda3/envs/tf2/lib/python3.9/site-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
# ---> 70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
#      72             del filtered_tb
#
# ~/miniconda3/envs/tf2/lib/python3.9/site-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      50   try:
#      51     ctx.ensure_initialized()
# ---> 52     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      53                                         inputs, attrs, num_outputs)
#      54   except core._NotOkStatusException as e:
#
# InvalidArgumentError: Graph execution error:
#
# Detected at node 'ConvNet/shift/map/TensorArrayUnstack/TensorListFromTensor' defined at (most recent call last):
#     File "/home/users/cdonoso/miniconda3/envs/tf2/lib/python3.9/runpy.py", line 197, in _run_module_as_main
#       return _run_code(code, main_globals, None,
#     File "/home/users/cdonoso/miniconda3/envs/tf2/lib/python3.9/runpy.py", line 87, in _run_code
#       exec(code, run_globals)
#     File "/home/users/cdonoso/miniconda3/envs/tf2/lib/python3.9/site-packages/ipykernel_launcher.py", line 17, in <module>
#       app.launch_new_instance()
#     File "/home/users/cdonoso/miniconda3/envs/tf2/lib/python3.9/site-packages/traitlets/config/application.py", line 976, in launch_instance
#       app.start()
#     File "/home/users/cdonoso/miniconda3/envs/tf2/lib/python3.9/site-packages/ipykernel/kernelapp.py", line 712, in start
#       self.io_loop.start()
#     File "/home/users/cdonoso/miniconda3/envs/tf2/lib/python3.9/site-packages/tornado/platform/asyncio.py", line 199, in start
#       self.asyncio_loop.run_forever()
#     File "/home/users/cdonoso/miniconda3/envs/tf2/lib/python3.9/asyncio/base_events.py", line 601, in run_forever
#       self._run_once()
#     File "/home/users/cdonoso/miniconda3/envs/tf2/lib/python3.9/asyncio/base_events.py", line 1905, in _run_once
#       handle._run()
#     File "/home/users/cdonoso/miniconda3/envs/tf2/lib/python3.9/asyncio/events.py", line 80, in _run
#       self._context.run(self._callback, *self._args)
#     File "/home/users/cdonoso/miniconda3/envs/tf2/lib/python3.9/site-packages/ipykernel/kernelbase.py", line 508, in dispatch_queue
#       await self.process_one()
#     File "/home/users/cdonoso/miniconda3/envs/tf2/lib/python3.9/site-packages/ipykernel/kernelbase.py", line 497, in process_one
#       await dispatch(*args)
#     File "/home/users/cdonoso/miniconda3/envs/tf2/lib/python3.9/site-packages/ipykernel/kernelbase.py", line 404, in dispatch_shell
#       await result
#     File "/home/users/cdonoso/miniconda3/envs/tf2/lib/python3.9/site-packages/ipykernel/kernelbase.py", line 728, in execute_request
#       reply_content = await reply_content
#     File "/home/users/cdonoso/miniconda3/envs/tf2/lib/python3.9/site-packages/ipykernel/ipkernel.py", line 383, in do_execute
#       res = shell.run_cell(
#     File "/home/users/cdonoso/miniconda3/envs/tf2/lib/python3.9/site-packages/ipykernel/zmqshell.py", line 528, in run_cell
#       return super().run_cell(*args, **kwargs)
#     File "/home/users/cdonoso/miniconda3/envs/tf2/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 2975, in run_cell
#       result = self._run_cell(
#     File "/home/users/cdonoso/miniconda3/envs/tf2/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3030, in _run_cell
#       return runner(coro)
#     File "/home/users/cdonoso/miniconda3/envs/tf2/lib/python3.9/site-packages/IPython/core/async_helpers.py", line 78, in _pseudo_sync_runner
#       coro.send(None)
#     File "/home/users/cdonoso/miniconda3/envs/tf2/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3257, in run_cell_async
#       has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#     File "/home/users/cdonoso/miniconda3/envs/tf2/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3473, in run_ast_nodes
#       if (await self.run_code(code, result,  async_=asy)):
#     File "/home/users/cdonoso/miniconda3/envs/tf2/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#       exec(code_obj, self.user_global_ns, self.user_ns)
#     File "/tmp/ipykernel_46912/1562732145.py", line 1, in <cell line: 1>
#       get_ipython().run_cell_magic('time', '', 'hist = model.fit(dataset, epochs=1000, callbacks=[es])\n')
#     File "/home/users/cdonoso/miniconda3/envs/tf2/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 2473, in run_cell_magic
#       result = fn(*args, **kwargs)
#     File "/home/users/cdonoso/miniconda3/envs/tf2/lib/python3.9/site-packages/decorator.py", line 232, in fun
#       return caller(func, *(extras + args), **kw)
#     File "/home/users/cdonoso/miniconda3/envs/tf2/lib/python3.9/site-packages/IPython/core/magic.py", line 187, in <lambda>
#       call = lambda f, *a, **k: f(*a, **k)
#     File "/home/users/cdonoso/miniconda3/envs/tf2/lib/python3.9/site-packages/IPython/core/magics/execution.py", line 1335, in time
#       exec(code, glob, local_ns)
#     File "<timed exec>", line 1, in <module>
#     File "/home/users/cdonoso/miniconda3/envs/tf2/lib/python3.9/site-packages/keras/utils/traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "/home/users/cdonoso/miniconda3/envs/tf2/lib/python3.9/site-packages/keras/engine/training.py", line 1650, in fit
#       tmp_logs = self.train_function(iterator)
#     File "/home/users/cdonoso/miniconda3/envs/tf2/lib/python3.9/site-packages/keras/engine/training.py", line 1249, in train_function
#       return step_function(self, iterator)
#     File "/home/users/cdonoso/miniconda3/envs/tf2/lib/python3.9/site-packages/keras/engine/training.py", line 1233, in step_function
#       outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "/home/users/cdonoso/miniconda3/envs/tf2/lib/python3.9/site-packages/keras/engine/training.py", line 1222, in run_step
#       outputs = model.train_step(data)
#     File "/home/users/cdonoso/NEGFC/src/model.py", line 62, in train_step
#       y_pred, _ = self(x, training=True)
#     File "/home/users/cdonoso/miniconda3/envs/tf2/lib/python3.9/site-packages/keras/utils/traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "/home/users/cdonoso/miniconda3/envs/tf2/lib/python3.9/site-packages/keras/engine/training.py", line 561, in __call__
#       return super().__call__(*args, **kwargs)
#     File "/home/users/cdonoso/miniconda3/envs/tf2/lib/python3.9/site-packages/keras/utils/traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "/home/users/cdonoso/miniconda3/envs/tf2/lib/python3.9/site-packages/keras/engine/base_layer.py", line 1132, in __call__
#       outputs = call_fn(inputs, *args, **kwargs)
#     File "/home/users/cdonoso/miniconda3/envs/tf2/lib/python3.9/site-packages/keras/utils/traceback_utils.py", line 96, in error_handler
#       return fn(*args, **kwargs)
#     File "/home/users/cdonoso/miniconda3/envs/tf2/lib/python3.9/site-packages/keras/engine/functional.py", line 511, in call
#       return self._run_internal_graph(inputs, training=training, mask=mask)
#     File "/home/users/cdonoso/miniconda3/envs/tf2/lib/python3.9/site-packages/keras/engine/functional.py", line 668, in _run_internal_graph
#       outputs = node.layer(*args, **kwargs)
#     File "/home/users/cdonoso/miniconda3/envs/tf2/lib/python3.9/site-packages/keras/utils/traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "/home/users/cdonoso/miniconda3/envs/tf2/lib/python3.9/site-packages/keras/engine/base_layer.py", line 1132, in __call__
#       outputs = call_fn(inputs, *args, **kwargs)
#     File "/home/users/cdonoso/miniconda3/envs/tf2/lib/python3.9/site-packages/keras/utils/traceback_utils.py", line 96, in error_handler
#       return fn(*args, **kwargs)
#     File "/home/users/cdonoso/NEGFC/src/layer.py", line 52, in call
#       x = tf.map_fn(lambda x: translate_image(x), (images, dx, dy, winsize), fn_output_signature=tf.float32)
# Node: 'ConvNet/shift/map/TensorArrayUnstack/TensorListFromTensor'
# Specified a list with shape [20,20,1] from a tensor with shape [15,15,1]
# 	 [[{{node ConvNet/shift/map/TensorArrayUnstack/TensorListFromTensor}}]] [Op:__inference_train_function_4773]

# %%
plt.plot(hist.history['loss'])

# %%
test_ds = create_dataset(cube, psf, rot_angles, table, batch_size=256, repeat=1)

# %%
pred = model.predict(test_ds)
# Out:
# 2/2 [==============================] - 2s 24ms/step

# %%
pred[2]
# Out:
# array([[[2373.378 ]],
#
#        [[2373.378 ]],
#
#        [[2373.378 ]],
#
#        [[2373.378 ]],
#
#        [[2373.378 ]],
#
#        [[2373.378 ]],
#
#        [[2373.378 ]],
#
#        [[2373.378 ]],
#
#        [[2373.378 ]],
#
#        [[2373.378 ]],
#
#        [[2373.378 ]],
#
#        [[2373.378 ]],
#
#        [[2373.378 ]],
#
#        [[2373.378 ]],
#
#        [[2373.378 ]],
#
#        [[2373.378 ]],
#
#        [[2373.378 ]],
#
#        [[2373.378 ]],
#
#        [[2373.378 ]],
#
#        [[2373.378 ]],
#
#        [[2373.378 ]],
#
#        [[2373.378 ]],
#
#        [[2373.378 ]],
#
#        [[2373.378 ]],
#
#        [[2373.378 ]],
#
#        [[2373.378 ]],
#
#        [[2373.378 ]],
#
#        [[2373.378 ]],
#
#        [[2373.378 ]],
#
#        [[2373.378 ]],
#
#        [[2373.378 ]],
#
#        [[2373.378 ]],
#
#        [[2373.378 ]],
#
#        [[2373.378 ]],
#
#        [[2373.378 ]],
#
#        [[2373.378 ]],
#
#        [[2373.378 ]],
#
#        [[2373.378 ]],
#
#        [[2373.378 ]],
#
#        [[2373.378 ]],
#
#        [[2373.44  ]],
#
#        [[2373.44  ]],
#
#        [[2373.44  ]],
#
#        [[2373.44  ]],
#
#        [[2373.44  ]],
#
#        [[2373.44  ]],
#
#        [[2373.44  ]],
#
#        [[2373.44  ]],
#
#        [[2373.44  ]],
#
#        [[2373.44  ]],
#
#        [[2373.44  ]],
#
#        [[2373.44  ]],
#
#        [[2373.44  ]],
#
#        [[2373.44  ]],
#
#        [[2373.44  ]],
#
#        [[2373.44  ]],
#
#        [[2373.44  ]],
#
#        [[2373.44  ]],
#
#        [[2373.44  ]],
#
#        [[2373.44  ]],
#
#        [[2373.44  ]],
#
#        [[2373.44  ]],
#
#        [[2373.44  ]],
#
#        [[2373.44  ]],
#
#        [[2373.44  ]],
#
#        [[2373.44  ]],
#
#        [[2373.44  ]],
#
#        [[2373.44  ]],
#
#        [[2373.44  ]],
#
#        [[2373.44  ]],
#
#        [[2373.44  ]],
#
#        [[2373.44  ]],
#
#        [[2373.44  ]],
#
#        [[2373.44  ]],
#
#        [[2373.44  ]],
#
#        [[2373.44  ]],
#
#        [[2373.44  ]],
#
#        [[2373.44  ]],
#
#        [[2373.44  ]],
#
#        [[2373.44  ]],
#
#        [[2278.3833]],
#
#        [[2278.3833]],
#
#        [[2278.3833]],
#
#        [[2278.3833]],
#
#        [[2278.3833]],
#
#        [[2278.3833]],
#
#        [[2278.3833]],
#
#        [[2278.3833]],
#
#        [[2278.3833]],
#
#        [[2278.3833]],
#
#        [[2278.3833]],
#
#        [[2278.3833]],
#
#        [[2278.3833]],
#
#        [[2278.3833]],
#
#        [[2278.3833]],
#
#        [[2278.3833]],
#
#        [[2278.3833]],
#
#        [[2278.3833]],
#
#        [[2278.3833]],
#
#        [[2278.3833]],
#
#        [[2278.3833]],
#
#        [[2278.3833]],
#
#        [[2278.3833]],
#
#        [[2278.3833]],
#
#        [[2278.3833]],
#
#        [[2278.3833]],
#
#        [[2278.3833]],
#
#        [[2278.3833]],
#
#        [[2278.3833]],
#
#        [[2278.3833]],
#
#        [[2278.3833]],
#
#        [[2278.3833]],
#
#        [[2278.3833]],
#
#        [[2278.3833]],
#
#        [[2278.3833]],
#
#        [[2278.3833]],
#
#        [[2278.3833]],
#
#        [[2278.3833]],
#
#        [[2278.3833]],
#
#        [[2278.3833]],
#
#        [[2278.4453]],
#
#        [[2278.4453]],
#
#        [[2278.4453]],
#
#        [[2278.4453]],
#
#        [[2278.4453]],
#
#        [[2278.4453]],
#
#        [[2278.4453]],
#
#        [[2278.4453]],
#
#        [[2278.4453]],
#
#        [[2278.4453]],
#
#        [[2278.4453]],
#
#        [[2278.4453]],
#
#        [[2278.4453]],
#
#        [[2278.4453]],
#
#        [[2278.4453]],
#
#        [[2278.4453]],
#
#        [[2278.4453]],
#
#        [[2278.4453]],
#
#        [[2278.4453]],
#
#        [[2278.4453]],
#
#        [[2278.4453]],
#
#        [[2278.4453]],
#
#        [[2278.4453]],
#
#        [[2278.4453]],
#
#        [[2278.4453]],
#
#        [[2278.4453]],
#
#        [[2278.4453]],
#
#        [[2278.4453]],
#
#        [[2278.4453]],
#
#        [[2278.4453]],
#
#        [[2278.4453]],
#
#        [[2278.4453]],
#
#        [[2278.4453]],
#
#        [[2278.4453]],
#
#        [[2278.4453]],
#
#        [[2278.4453]],
#
#        [[2278.4453]],
#
#        [[2278.4453]],
#
#        [[2278.4453]],
#
#        [[2278.4453]],
#
#        [[2263.2039]],
#
#        [[2263.2039]],
#
#        [[2263.2039]],
#
#        [[2263.2039]],
#
#        [[2263.2039]],
#
#        [[2263.2039]],
#
#        [[2263.2039]],
#
#        [[2263.2039]],
#
#        [[2263.2039]],
#
#        [[2263.2039]],
#
#        [[2263.2039]],
#
#        [[2263.2039]],
#
#        [[2263.2039]],
#
#        [[2263.2039]],
#
#        [[2263.2039]],
#
#        [[2263.2039]],
#
#        [[2263.2039]],
#
#        [[2263.2039]],
#
#        [[2263.2039]],
#
#        [[2263.2039]],
#
#        [[2263.2039]],
#
#        [[2263.2039]],
#
#        [[2263.2039]],
#
#        [[2263.2039]],
#
#        [[2263.2039]],
#
#        [[2263.2039]],
#
#        [[2263.2039]],
#
#        [[2263.2039]],
#
#        [[2263.2039]],
#
#        [[2263.2039]],
#
#        [[2263.2039]],
#
#        [[2263.2039]],
#
#        [[2263.2039]],
#
#        [[2263.2039]],
#
#        [[2263.2039]],
#
#        [[2263.2039]],
#
#        [[2263.2039]],
#
#        [[2263.2039]],
#
#        [[2263.2039]],
#
#        [[2263.2039]],
#
#        [[2263.2659]],
#
#        [[2263.2659]],
#
#        [[2263.2659]],
#
#        [[2263.2659]],
#
#        [[2263.2659]],
#
#        [[2263.2659]],
#
#        [[2263.2659]],
#
#        [[2263.2659]],
#
#        [[2263.2659]],
#
#        [[2263.2659]],
#
#        [[2263.2659]],
#
#        [[2263.2659]],
#
#        [[2263.2659]],
#
#        [[2263.2659]],
#
#        [[2263.2659]],
#
#        [[2263.2659]],
#
#        [[2263.2659]],
#
#        [[2263.2659]],
#
#        [[2263.2659]],
#
#        [[2263.2659]],
#
#        [[2263.2659]],
#
#        [[2263.2659]],
#
#        [[2263.2659]],
#
#        [[2263.2659]],
#
#        [[2263.2659]],
#
#        [[2263.2659]],
#
#        [[2263.2659]],
#
#        [[2263.2659]],
#
#        [[2263.2659]],
#
#        [[2263.2659]],
#
#        [[2263.2659]],
#
#        [[2263.2659]],
#
#        [[2263.2659]],
#
#        [[2263.2659]],
#
#        [[2263.2659]],
#
#        [[2263.2659]],
#
#        [[2263.2659]],
#
#        [[2263.2659]],
#
#        [[2263.2659]],
#
#        [[2263.2659]]], dtype=float32)
